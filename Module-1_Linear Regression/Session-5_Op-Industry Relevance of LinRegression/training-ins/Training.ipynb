# %%
n=int(input())

sum = 0

for digit in str(n):
    sum+=int(digit)

if sum %2 == 0:
    print('even')
else:
    print('odd')
# Out:
# 123456
# odd

# %%
import ast, sys
input_str = sys.stdin.read()
input_list = ast.literal_eval(input_str)

for i in range(1,len(input_list)):
    if input_list[i] <= input_list[i + 1]:
        return "yes"
    else:
      return "no"
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-13-6f8cebdfa363>", line 3, in <cell line: 3>
#     input_list = ast.literal_eval(input_str)
#
#   File "/usr/lib/python3.10/ast.py", line 64, in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File "/usr/lib/python3.10/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line unknown
#
#     ^
# SyntaxError: invalid syntax

# %%
range(len([1,2,3,4,5,6]))
# Out:
# range(0, 6)

# %%
input_list = [1,2,3,5,6]

for i in range(1,len(input_list)):
    if input_list[i] <= input_list[i-1]:
        print("no")
        break  # Exit the loop when the condition is not met
else:
    print("yes")
# Out:
# yes

# %%
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/OzvzVqK4pgg4x7qEadoZMRyVR/insurance.csv")

# Function to categorize BMI into groups
def categorize_bmi(bmi):
    if bmi > 30:
        return 'Obese'
    elif 25 <= bmi <= 29.9:
        return 'Overweight'
    elif 18.5 <= bmi <= 24.9:
        return 'Normal'
    elif bmi < 18.5:
        return 'Underweight'
    else:
        return 'Unknown'

# Apply the function to create the 'BMI_group' column
df['BMI_group'] = df['bmi'].apply(categorize_bmi)

# Display the DataFrame with the new column
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges   BMI_group
# 0   19  female  27.900         0    yes  southwest  16884.92400  Overweight
# 1   18    male  33.770         1     no  southeast   1725.55230       Obese
# 2   28    male  33.000         3     no  southeast   4449.46200       Obese
# 3   33    male  22.705         0     no  northwest  21984.47061      Normal
# 4   32    male  28.880         0     no  northwest   3866.85520  Overweight

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/OzvzVqK4pgg4x7qEadoZMRyVR/insurance.csv")

# Function to categorize BMI into groups
def categorize_bmi(bmi):
    if bmi > 30:
        return 'Obese'
    elif 25 <= bmi <= 29.9:
        return 'Overweight'
    elif 18.5 <= bmi <= 24.9:
        return 'Normal'
    elif bmi < 18.5:
        return 'Underweight'
    else:
        return 'Unknown'

# Apply the function to create the 'BMI_group' column
df['BMI_group'] = df['bmi'].apply(categorize_bmi)

# Display the DataFrame with the new column
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges   BMI_group
# 0   19  female  27.900         0    yes  southwest  16884.92400  Overweight
# 1   18    male  33.770         1     no  southeast   1725.55230       Obese
# 2   28    male  33.000         3     no  southeast   4449.46200       Obese
# 3   33    male  22.705         0     no  northwest  21984.47061      Normal
# 4   32    male  28.880         0     no  northwest   3866.85520  Overweight

# %%
import pandas as pd
df=pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/OzvzVqK4pgg4x7qEadoZMRyVR/insurance.csv")
df.head()

def grp(bmi):
    if bmi >= 30:
        return 'Obese'
    elif 25 <= bmi <= 29.9:
        return 'Overweight'
    elif 18.5 <= bmi <= 24.9:
        return 'Normal'
    elif bmi <= 18.5:
        return 'Underweight'

df['BMI_group'] = df['bmi'].apply(grp)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges   BMI_group
# 0   19  female  27.900         0    yes  southwest  16884.92400  Overweight
# 1   18    male  33.770         1     no  southeast   1725.55230       Obese
# 2   28    male  33.000         3     no  southeast   4449.46200       Obese
# 3   33    male  22.705         0     no  northwest  21984.47061      Normal
# 4   32    male  28.880         0     no  northwest   3866.85520  Overweight

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
pd.set_option('display.max_columns', 500)
df=pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/831JKKEkW7kqd5M4evNva9LyB/insurance_grouped.csv")
df.head()

le = LabelEncoder()#use this encoder to encode values

df['BMI_group'].fillna('Unknown', inplace=True)
cat_vars = ['sex', 'smoker', 'region', 'BMI_group']

# Encode each categorical variable and update the DataFrame
for var in cat_vars:
    df[var] = le.fit_transform(df[var])

df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  BMI_group
# 0   19    0  27.900         0       1       3  16884.92400          2
# 1   18    1  33.770         1       0       2   1725.55230          1
# 2   28    1  33.000         3       0       2   4449.46200          1
# 3   33    1  22.705         0       0       1  21984.47061          0
# 4   32    1  28.880         0       0       1   3866.85520          2

# %%
import pandas as pd
df=pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/B5yO4wkEbQk4dVGn8140yV1bx/insurance_encoded.csv")

correlation_bmi = df['smoker'].corr(df['bmi'])
correlation_age = df['smoker'].corr(df['age'])
correlation_charges = df['smoker'].corr(df['charges'])

print(f"{correlation_bmi:.4f}")
print(f"{correlation_age:.4f}")
print(f"{correlation_charges:.4f}")
# Out:
# 0.0038
# -0.0250
# 0.7873

# %%
import numpy as np
import pandas as pd

# Read training data
train = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/72Boxj99702g8BwK5powGz1g0/insurance_training.csv")

# Read test data
test = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/gxVjwe1k3YEogYK23O8PPnXod/insurance_test.csv")

# Linear regression

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
import statsmodels.api as sm

X_train = train['smoker']
y_train = train['charges']

#X = sm.add_constant(X_train)

lm = sm.OLS(y_train,X_train).fit()

print(lm.summary())

y_test_pred = lm.predict(test['smoker'])


# Write the output
#THESE TWO LINES SHOULD NOT BE EDITED
#test["predicted_charges"]=y_test_pred
#test.to_csv("/code/output/predictions.csv")
# Out:
#       Unnamed: 0  age  sex     bmi  children  smoker  region  BMI_group  \
# 0            560   46    0  19.950         2       0       1          1
# 1           1285   47    0  24.320         0       0       0          1
# 2           1142   52    0  24.860         0       0       2          1
# 3            969   39    0  34.320         5       0       2          2
# 4            486   54    0  21.470         3       0       1          1
# ...          ...  ...  ...     ...       ...     ...     ...        ...
# 1065        1095   18    0  31.350         4       0       0          2
# 1066        1130   39    0  23.870         5       0       2          1
# 1067        1294   58    1  25.175         0       0       0          3
# 1068         860   37    0  47.600         2       1       3          2
# 1069        1126   55    1  29.900         0       0       3          3
#
#           charges
# 0      9193.83850
# 1      8534.67180
# 2     27117.99378
# 3      8596.82780
# 4     12475.35130
# ...           ...
# 1065   4561.18850
# 1066   8582.30230
# 1067  11931.12525
# 1068  46113.51100
# 1069  10214.63600
#
# [1070 rows x 9 columns]

# %%
import numpy as np
import pandas as pd

# Read training data
train = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/QNdMORzykKkG4L3WQ17Xx53o3/insurance_training.csv")

# Read test data
test = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/Mq5p8YpQoz3KbWJRE4Mey1Yoq/insurance_test.csv")

# Linear regression
#import required libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
import statsmodels.api as sm

scaler = MinMaxScaler()

cols = ['children', 'smoker', 'bmi']

X_train = train[cols]

X = scaler.fit_transform(X_train)


y_train = train['charges']

lm = sm.OLS(y_train,X).fit()
print(lm.summary())

from statsmodels.stats.outliers_influence import variance_inflation_factor

X_vif = X_train
vif = pd.DataFrame()
vif['Features'] = X_vif.columns
vif['VIF'] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by="VIF", ascending = False)
print(vif)


X_test = test[cols]

X_test_scaled = scaler.transform(X_test)
y_test_pred = lm.predict(X_test_scaled)


# Write the output
#test["predicted_charges"]=y_test_pred
#test.to_csv("/code/output/predictions.csv")
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                charges   R-squared (uncentered):                   0.843
# Model:                            OLS   Adj. R-squared (uncentered):              0.842
# Method:                 Least Squares   F-statistic:                              1905.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):                        0.00
# Time:                        11:26:45   Log-Likelihood:                         -11010.
# No. Observations:                1070   AIC:                                  2.203e+04
# Df Residuals:                    1067   BIC:                                  2.204e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          4051.5594    848.371      4.776      0.000    2386.895    5716.224
# x2          2.351e+04    530.858     44.288      0.000    2.25e+04    2.46e+04
# x3          1.872e+04    685.713     27.298      0.000    1.74e+04    2.01e+04
# ==============================================================================
# Omnibus:                      125.428   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              196.041
# Skew:                           0.810   Prob(JB):                     2.69e-43
# Kurtosis:                       4.332   Cond. No.                         2.51
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#    Features   VIF
# 2       bmi  1.99
# 0  children  1.77
# 1    smoker  1.25

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()

rfe = RFE(estimator = lm, n_features_to_select = 5)             # Running RFE

cols_all = ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'BMI_group']

X_train = train[cols_all]

rfe = rfe.fit(X_train, y_train)

list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('age', False, 2),
#  ('sex', False, 3),
#  ('bmi', True, 1),
#  ('children', True, 1),
#  ('smoker', True, 1),
#  ('region', True, 1),
#  ('BMI_group', True, 1)]
